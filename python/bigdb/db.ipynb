# %%
import os, re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# CSV 파일을 읽기
os.chdir(r'D:\python\bigdb')
df = pd.read_csv('score.csv', thousands=',', encoding='utf-8')
print(df)
df2 = df[(df['korean_score'] < 101) & (df['math_score'] <101 ) & (df['english_score'] <101 ) & (df['science_score'] <101 )] 
print(df2)
print(df2['name'].value_counts())
df2.sort_values(by='korean_score', ascending=False).loc[:, ['name','korean_score']]
df2.sort_values(by='math_score', ascending=False).loc[:, ['name','math_score']]
df2.sort_values(by='english_score', ascending=False).loc[:, ['name','english_score']]
df2.sort_values(by='science_score', ascending=False).loc[:, ['name','science_score']]

korean_total_score = {'Jane': 100,
                    'Rahell': 95,
                    'July': 90,
                    'Julia': 88,
                    'Aladin': 86,
                    'Jon': 85,
                    'Jason': 81,
                    'Smith': 78,
                    'Jisu': 75,
                    'Jony': 71,
                    'Jone': 65,
                    'Jene': 64,
                    'Mikle': 55,
                    'Kally': 51,
                    'Alibaba': 45,
                    'James': 45,
                    'Recheal': 45}
group_data = list(korean_total_score.values())
group_names = list(korean_total_score.keys())
group_mean = np.mean(group_data)
fig, ax = plt.subplots()
ax.barh(group_names, group_data)

math_total_score = {'Aladin': 99,
                    'Julia': 92,
                    'Rahell': 88,
                    'Jisu': 85,
                    'James': 85,
                    'Jony': 82,
                    'Jason': 81,
                    'July': 80,
                    'Recheal': 78,
                    'Mikle': 77,
                    'Jene': 62,
                    'Jone': 55,
                    'Jane': 55,
                    'Kally': 52,
                    'Smith': 45,
                    'Alibaba': 45,
                    'Jon': 15}
group_data2 = list(math_total_score.values())
group_names2 = list(math_total_score.keys())
group_mean2 = np.mean(group_data2)
fig, ax = plt.subplots()
ax.barh(group_names2, group_data2)

english_total_score = {'Jason': 95,
                    'Jisu': 95,
                    'Jony': 83,
                    'Jene': 81,
                    'July': 77,
                    'James': 76,
                    'Rahell': 76,
                    'Julia': 74,
                    'Jone': 68,
                    'Jane': 65,
                    'Alibaba': 65,
                    'Kally': 55,
                    'Jon': 46,
                    'Mikle': 45,
                    'Aladin': 45,
                    'Smith': 32,
                    'Recheal': 12}
group_data2 = list(english_total_score.values())
group_names2 = list(english_total_score.keys())
group_mean2 = np.mean(group_data2)
fig, ax = plt.subplots()
ax.barh(group_names2, group_data2)

science_total_score = {'Jony': 99,
                    'Recheal': 95,
                    'Jene': 91,
                    'Jon': 85,
                    'Alibaba': 85,
                    'July': 82,
                    'Mikle': 75,
                    'Rahell': 75,
                    'Julia': 71,
                    'Jone': 67,
                    'Kally': 57,
                    'James': 48,
                    'Jason': 42,
                    'Jane': 30,
                    'Jisu': 15,
                    'Smith': 12,
                    'Aladin': 12}
group_data2 = list(science_total_score.values())
group_names2 = list(science_total_score.keys())
group_mean2 = np.mean(group_data2)
fig, ax = plt.subplots()
ax.barh(group_names2, group_data2)
# Out:
#    sex     name  korean_score  math_score  english_score  science_score
# 0    f     Jane           100          55             65             30
# 1    m    Mikle            55          77             45             75
# 2    f      Jon            85          15             46             85
# 3    f     Jisu            75          85             95             15
# 4    m    James            45          85             76             48
# 5    m   Aladin            86          99             45             12
# 6    m  Alibaba            45          45             65             85
# 7    m    Smith            78          45             32             12
# 8    f  Recheal            45          78             12             95
# 9    f   Rahell            95          88             76             75
# 10   f     July            90          80             77             82
# 11   f    Julia            88          92             74             71
# ...
